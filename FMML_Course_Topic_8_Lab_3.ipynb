# %% [markdown]
# <a href="https://colab.research.google.com/github/RayapureddyBhaskar/FMML_PROJECTS_AND_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-13 14:22:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   225MB/s    in 0.3s
#
# 2024-04-13 14:22:58 (225 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2718 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9118    1401.3488v1  We present a novel Bayesian topic model for le...    cs
# 33657  1506.05427v1  Neuromorphic chips embody computational princi...    cs
# 7119   1710.06273v2  We consider the homogeneous and the non-homoge...    cs
# 37054  1606.01924v2  Space situational awareness (SSA) is vital for...    cs
# 36726   1404.1685v3  In this paper we discuss some reasons why temp...    cs
# ...             ...                                                ...   ...
# 30753  1801.02101v1  Confocal laser endomicroscopy (CLE), although ...    cs
# 35791   1208.1940v1  Game tree search algorithms such as minimax ha...    cs
# 30369  1712.00721v1  Recent years have witnessed promising results ...    cs
# 11879  1703.02723v1  Greedy algorithms are widely used for problems...  stat
# 33708  1601.04296v1  This article deals with an important aspect of...    cs
#
#                                                    title  year  \
# 9118          Content Modeling Using Latent Permutations  2014
# 33657  Real time unsupervised learning of visual stim...  2015
# 7119   Combinatorial Penalties: Which structures are ...  2017
# 37054  Preliminaries of a Space Situational Awareness...  2016
# 36726                         Thou Shalt is not You Will  2014
# ...                                                  ...   ...
# 30753  Improving utility of brain tumor confocal lase...  2018
# 35791  Experiments with Game Tree Search in Real-Time...  2012
# 30369  Feature Agglomeration Networks for Single Stag...  2017
# 11879  Scalable Greedy Feature Selection via Weak Sub...  2017
# 33708  Building a Learning Database for the Neural Ne...  2016
#
#                                                 keywords
# 9118   [discourse, structure, leverages, discourse, c...
# 33657  [neuromorphic, computational, principles, oper...
# 7119   [homogeneous, homogeneous, relaxations, combin...
# 37054  [situational, awareness, international, improv...
# 36726  [dutyderived, permission, interaction, obligat...
# ...                                                  ...
# 30753  [endomicroscopy, obtaining, resolution, diagno...
# 35791  [algorithms, adversarial, algorithms, mechanic...
# 30369  [witnessed, promising, detection, especially, ...
# 11879  [algorithms, selection, optimization, unfortun...
# 33708  [important, retrieval, brightness, temperature...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9118     [discourse, structure, leverages, discourse, c...
# 33657    [neuromorphic, computational, principles, oper...
# 7119     [homogeneous, homogeneous, relaxations, combin...
# 37054    [situational, awareness, international, improv...
# 36726    [dutyderived, permission, interaction, obligat...
#                                ...
# 19163    [suggested, inference, inference, furthermore,...
# 11745    [safeguarding, desirable, especially, collabor...
# 34652    [answering, selection, candidate, sentences, d...
# 9333     [stochastic, variational, inference, algorithm...
# 1058     [introduce, permutation, equivariant, structur...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8704 words.
# Out of those 4617 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="caec1c11-83bb-4a49-9ac3-be75b654fb1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caec1c11-83bb-4a49-9ac3-be75b654fb1e")) {                    Plotly.newPlot(                        "caec1c11-83bb-4a49-9ac3-be75b654fb1e",                        [{"x":["generalized","permutation","alignment","experiments","selection","discourse","effectively","structure","documents","segmentation","constrain","substantial","distribution","orderings","organization","incorporating","leverages","assignments","complementary","performance","underlying","improvements","permutations","represented","information","collection","previously","applications","microelectronic","attractors","artificial","determined","implement","activating","important","selective","neuromorphic","parameters","recurrent","attractor","autonomous","supporting","computational","unsupervised","retrieval","primitives","corresponding","presentation","plasticity","associative","following","prototypical","cognitive","comprises","equilibrium","implements","principles","demonstrated","attraction","relaxation","separation","operating","connectivity","memorized","estimator","relaxations","regularizers","identification","conditions","combinatorial","asymptotic","differences","necessary","functions","resulting","tightness","sufficient","penalties","identifies","preserved","homogeneous","structures","requirements","awareness","knowledge","generations","exploring","improving","described","integration","engineering","discipline","situational","databases","environment","represent","scientific","repositories","development","international","desiderata","objectives","potential","relationships","planetary","interaction","obligations","permission","permissions","manipulated","performed","parallelized","automatic","surrounding","specifically","erroneous","indicated","especially","improvement","correction","otherwise","advantage","multiprocessor","converting","different","recognized","technology","submitted","suggestion","recognition","validated","suggested","languages","computers","algorithm","successful","imprecise","continues","achieving","classification","classifieds","vocabulary","platforms","intelligence","calculated","considered","supervised","bioinformatics","connected","prediction","remarkable","collaborative","techniques","activation","processing","convolutional","categories","transformed","formulating","approximate","associated","uncertainties","dimensional","efficient","stochastic","optimization","nonlinear","formulations","classifiers","approximation","uncertainty","multidimensional","investigates","generative","mathematical","addressed","generalization","theoretical","questions","approaches","foundations","embedding","complexity","dimension","empirical","introducing","polynomial","procedure","evaluation","robustness","constraint","outperforms","supermatch","instances","solutions","programming","demonstrates","particularly","interventions","attention"],"y":[66,9,52,605,163,24,106,326,67,191,9,39,216,4,19,63,34,9,38,876,119,119,4,70,731,68,90,456,2,2,120,38,66,2,356,19,9,254,144,3,43,15,313,155,113,8,118,10,6,8,79,7,50,14,13,16,35,118,2,18,18,23,22,1,22,6,9,99,152,40,17,60,67,211,147,4,78,4,19,14,16,147,52,6,398,11,38,90,65,39,53,3,2,64,125,103,32,7,140,20,1,26,154,54,3,80,2,3,2,6,122,10,183,13,191,7,7,116,149,21,16,101,3,12,727,21,63,17,4,381,36,36,84,20,817,69,8,9,87,527,2,47,32,85,33,141,188,9,66,220,25,42,385,37,267,367,73,25,12,119,113,9,172,387,126,317,56,15,99,98,73,14,26,124,57,31,117,157,58,431,12,108,229,52,161,50,58,119,247,102,94,277,2,102,152,119,61,69,3,162],"type":"bar"},{"x":["generalized","permutation","alignment","experiments","selection","discourse","effective ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4617,), (4617, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scale</span> <span style='background-color:rgba(0, 255, 0, 0.32727272727272727);'>invariant</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>unconstrained</span> <span style=''>online</span> <span style=''>learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>in</span> <span style=''>which</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3691275167785235);'>instances</span> <span style=''>(input</span> <span style=''>vectors)</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparator</span> <span style=''>(weight</span> <span style=''>vector)</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>unconstrained</span> <span style=''>We</span> <span style=''>exploit</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>invariance</span> <span style=''>symmetry</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.4358974358974359);'>unconstrained</span> <span style=''>setting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparator</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.32727272727272727);'>invariant</span> <span style=''>under</span> <span style=''>any</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3691275167785235);'>instances</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>design</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>also</span> <span style=''>enjoy</span> <span style=''>this</span> <span style=''>property</span> <span style=''>ie</span> <span style=''>are</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.32727272727272727);'>invariant</span> <span style=''>We</span> <span style=''>start</span> <span style=''>with</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>coordinate</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.6756756756756757);'>invariance</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>(features)</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.4857142857142857);'>arbitrarily</span> <span style=''>rescaled</span> <span style=''>We</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>achieves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>optimal</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setup</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressed</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonconvex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>(SGD)</span> <span style=''>method</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonconvex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>from</span> <span style=''>the</span> <span style=''>point</span> <span style=''>of</span> <span style=''>view</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>We</span> <span style=''>prove</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rigorously</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>process</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style=''>SGD</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>weakly</span> <span style=''>using</span> <span style=''>the</span> <span style=''>weak</span> <span style=''>form</span> <span style=''>of</span> <span style=''>master</span> <span style=''>equation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <span style=''>In</span> <span style=''>the</span> <span style=''>small</span> <span style=''>step</span> <span style=''>size</span> <span style=''>regime</span> <span style=''>and</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>omnidirectional</span> <span style=''>noise</span> <span style=''>our</span> <span style=''>weak</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>process</span> <span style=''>suggests</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>dynamics</span> <span style=''>for</span> <span style=''>the</span> <span style=''>SGD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>starting</span> <span style=''>from</span> <span style=''>a</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizer</span> <span style=''>(respsaddle</span> <span style=''>point)</span> <span style=''>it</span> <span style=''>escapes</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>(respalmost</span> <span style=''>linearly)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>on</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>stepsize</span> <span style=''>The</span> <span style=''>results</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>using</span> <span style=''>the</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Online</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>by</span> <span style=''>Putting</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Forecaster</span> <span style=''>to</span> <span style=''>Sleep</span> <br/><br/><span style=''>Methods</span> <span style=''>from</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857144);'>accelerated</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>as</span> <span style=''>building</span> <span style=''>blocks</span> <span style=''>for</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>However</span> <span style=''>the</span> <span style=''>reasons</span> <span style=''>for</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>success</span> <span style=''>are</span> <span style=''>unclear</span> <span style=''>since</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>not</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.32121212121212117);'>guarantees</span> <span style=''>do</span> <span style=''>not</span> <span style=''>apply</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>develops</span> <span style=''>the</span> <span style=''>first</span> <span style=''>rigorous</span> <span style=''>link</span> <span style=''>between</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>backpropagation</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.5921908893709328);'>convolutional</span> <span style=''>networks</span> <span style=''>The</span> <span style=''>first</span> <span style=''>step</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>circadian</span> <span style=''>games</span> <span style=''>a</span> <span style=''>mild</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>convex</span> <span style=''>games</span> <span style=''>with</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.30927835051546393);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>The</span> <span style=''>main</span> <span style=''>result</span> <span style=''>is</span> <span style=''>that</span> <span style=''>error</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>backpropagation</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5921908893709328);'>convolutional</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>playing</span> <span style=''>out</span> <span style=''>a</span> <span style=''>circadian</span> <span style=''>game</span> <span style=''>It</span> <span style=''>follows</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>immediately</span> <span style=''>that</span> <span style=''>the</span> <span style=''>waking</span> <span style=''>regret</span> <span style=''>of</span> <span style=''>players</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>from</span> <span style=''>Clinical</span> <span style=''>Notes</span> <br/><br/><span style=''>Clinical</span> <span style=''>notes</span> <span style=''>are</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>source</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>patient</span> <span style=''>state</span> <span style=''>However</span> <span style=''>using</span> <span style=''>them</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>presents</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>summarizing</span> <span style=''>clinical</span> <span style=''>notes</span> <span style=''>into</span> <span style=''>patient</span> <span style=''>level</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>on</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>tasks</span> <span style=''>and</span> <span style=''>cohort</span> <span style=''>sizes</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>offer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>gains</span> <span style=''>over</span> <span style=''>the</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>baselines</span> <span style=''>of</span> <span style=''>Bag</span> <span style=''>of</span> <span style=''>Words</span> <span style=''>and</span> <span style=''>topic</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>across</span> <span style=''>all</span> <span style=''>tested</span> <span style=''>tasks</span> <span style=''>and</span> <span style=''>cohort</span> <span style=''>sizes</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.0951193444959031)
# 	challenging (0.09725685785536159)
# 	representation (0.12540078375489846)
# 	segmentation (0.06804417527609548)
# 	detection (0.11542572141075881)
# 	information (0.26042037762736014)
# 	different (0.2589953687210545)
# 	knowledge (0.1417883861774136)
# 	convolutional (0.1307445671535447)
# 	recognition (0.13573209832561453)
#
# Some Statistics words are:
# 	stochastic (0.13146011038635222)
# 	algorithm (0.388861013547416)
# 	statistical (0.15253386853988962)
# 	variables (0.13948820873055695)
# 	estimation (0.17561465127947817)
# 	distribution (0.18564977420973408)
# 	theoretical (0.16658304064224785)
# 	inference (0.19568489713998996)
# 	dimensional (0.1846462619167085)
# 	regression (0.18013045659809332)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96c8fc6a-4c8e-4da6-bdb6-5742bb635702" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96c8fc6a-4c8e-4da6-bdb6-5742bb635702")) {                    Plotly.newPlot(                        "96c8fc6a-4c8e-4da6-bdb6-5742bb635702",                        [{"x":["generalized","permutation","alignment","experiments","selection","discourse","effectively","structure","documents","segmentation","constrain","substantial","distribution","orderings","organization","incorporating","leverages","assignments","complementary","performance","underlying","improvements","permutations","represented","information","collection","previously","applications","microelectronic","attractors","artificial","determined","implement","activating","important","selective","neuromorphic","parameters","recurrent","attractor","autonomous","supporting","computational","unsupervised","retrieval","primitives","corresponding","presentation","plasticity","associative","following","prototypical","cognitive","comprises","equilibrium","implements","principles","demonstrated","attraction","relaxation","separation","operating","connectivity","memorized","estimator","relaxations","regularizers","identification","conditions","combinatorial","asymptotic","differences","necessary","functions","resulting","tightness","sufficient","penalties","identifies","preserved","homogeneous","structures","requirements","awareness","knowledge","generations","exploring","improving","described","integration","engineering","discipline","situational","databases","environment","represent","scientific","repositories","development","international","desiderata","objectives","potential","relationships","planetary","interaction","obligations","permission","permissions","manipulated","performed","parallelized","automatic","surrounding","specifically","erroneous","indicated","especially","improvement","correction","otherwise","advantage","multiprocessor","converting","different","recognized","technology","submitted","suggestion","recognition","validated","suggested","languages","computers","algorithm","successful","imprecise","continues","achieving","classification","classifieds","vocabulary","platforms","intelligence","calculated","considered","supervised","bioinformatics","connected","prediction","remarkable","collaborative","techniques","activation","processing","convolutional","categories","transformed","formulating","approximate","associated","uncertainties","dimensional","efficient","stochastic","optimization","nonlinear","formulations","classifiers","approximation","uncertainty","multidimensional","investigates","generative","mathematical","addressed","generalization","theoretical","questions","approaches","foundations","embedding","complexity","dimension","empirical","introducing","polynomial","procedure","evaluation","robustness","constraint","outperforms","supermatch","instances","solutions","programming","demonstrates","particularly","interventions","attention","equivalent","estimating","photographs","inexpensive","corrected","refractive","participants","correlated","predictions","contribute","contained","attachments","available","impairment","algorithms","prescribing","spherical","predicting","theoretic","communication","particular","strategies","obtaining","presented","importance","experimental","incorporated","substitute","fundamental","outperform","processes","statistical","characterizing","distributed","calculations","committee","suboptimal","quantization","practical","candidates","terminologies","extraction","biomedical","impossibility","extractor","involving","implemented","linguistic","influence","difficulty","resources","decreasing","limitation","technical","additional","perform ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	changepoints
# 	martingales
# 	parametrisation
# 	manifested
# 	diagonalise
# 	expectimax
# 	groundwork
# 	spectroradiometer
# 	penalizations
# 	amortised
# 	investing
# 	concordant
# 	inversions
# 	dermatological
# 	trilinear
# 	quantiles
# 	elegantly
# 	strikingly
# 	gribonval
# 	oscillations
# Some words which never appear in Statistics papers:
# 	discourse
# 	orderings
# 	microelectronic
# 	neuromorphic
# 	awareness
# 	situational
# 	obligations
# 	permission
# 	permissions
# 	multiprocessor
# 	classifieds
# 	supermatch
# 	photographs
# 	refractive
# 	attachments
# 	terminologies
# 	extractors
# 	terminological
# 	disambiguation
# 	velocities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059320219047328e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
